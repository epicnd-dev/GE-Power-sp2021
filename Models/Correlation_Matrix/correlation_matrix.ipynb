# %%
# libraries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
#correlation_mat = df_2013.corr()
df = [pd.read_csv(f'Test/{x.strip()}') for x in os.popen('ls Test/')]
data = pd.concat(df)
correlation_mat = data.corr()
sns.heatmap(correlation_mat, annot = True)
plt.show()
